# %% [markdown]
# <a href="https://colab.research.google.com/github/USMS-FPK-IA-GI-2025/controle01-numpy-matplotlib-iris/blob/main/notebooks/controle_numpy_matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Contrôle 01 — Data Science avec NumPy et Matplotlib
# **Master 1 — Intelligence Artificielle & Génie Informatique (FPK / USMS)**
#
# Nom & Prénom :  CHOUAIB JBEL
# Filière :  SIIA
# Année universitaire : 2025/2026
#
# ---
#
# **Règles :**
# - Bibliothèques autorisées : NumPy, Matplotlib
# - Toute autre bibliothèque est interdite
# - Chaque question doit être traitée dans une cellule dédiée
# - Chaque résultat doit être brièvement interprété

# %% [markdown]
# # Partie A — Importation du Dataset, Arrays, Premières Manipulations

# %% [markdown]
# ### A1. Importation du dataset
# Importez NumPy et Matplotlib.
# Chargez le fichier `iris.csv` avec `np.genfromtxt` (`delimiter=','`, `skip_header=1`).
# Stockez les données dans un array nommé `data` et affichez sa `shape`.

# %%
# Votre code ici
import numpy as np 
import matplotlib.pyplot as plt

data = np.genfromtxt('..\data\Iris.csv', delimiter=',', dtype=str, skip_header=1)

# %% [markdown]
# ### A2. Séparation des features et des espèces
# Séparez :
# - les 4 premières colonnes numériques dans un array `features`
# - la dernière colonne (espèces) dans un array `species`
# Utilisez le slicing.

# %%
# Votre code ici
features = data[:, 1:5].astype(float) 
species = data[:, -1]
print(features.shape, species.shape)
print(features)
print(species)
# Out:
# (150, 4) (150,)
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]
#  [5.4 3.9 1.7 0.4]
#  [4.6 3.4 1.4 0.3]
#  [5.  3.4 1.5 0.2]
#  [4.4 2.9 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.4 3.7 1.5 0.2]
#  [4.8 3.4 1.6 0.2]
#  [4.8 3.  1.4 0.1]
#  [4.3 3.  1.1 0.1]
#  [5.8 4.  1.2 0.2]
#  [5.7 4.4 1.5 0.4]
#  [5.4 3.9 1.3 0.4]
#  [5.1 3.5 1.4 0.3]
#  [5.7 3.8 1.7 0.3]
#  [5.1 3.8 1.5 0.3]
#  [5.4 3.4 1.7 0.2]
#  [5.1 3.7 1.5 0.4]
#  [4.6 3.6 1.  0.2]
#  [5.1 3.3 1.7 0.5]
#  [4.8 3.4 1.9 0.2]
#  [5.  3.  1.6 0.2]
#  [5.  3.4 1.6 0.4]
#  [5.2 3.5 1.5 0.2]
#  [5.2 3.4 1.4 0.2]
#  [4.7 3.2 1.6 0.2]
#  [4.8 3.1 1.6 0.2]
#  [5.4 3.4 1.5 0.4]
#  [5.2 4.1 1.5 0.1]
#  [5.5 4.2 1.4 0.2]
#  [4.9 3.1 1.5 0.1]
#  [5.  3.2 1.2 0.2]
#  [5.5 3.5 1.3 0.2]
#  [4.9 3.1 1.5 0.1]
#  [4.4 3.  1.3 0.2]
#  [5.1 3.4 1.5 0.2]
#  [5.  3.5 1.3 0.3]
#  [4.5 2.3 1.3 0.3]
#  [4.4 3.2 1.3 0.2]
#  [5.  3.5 1.6 0.6]
#  [5.1 3.8 1.9 0.4]
#  [4.8 3.  1.4 0.3]
#  [5.1 3.8 1.6 0.2]
#  [4.6 3.2 1.4 0.2]
#  [5.3 3.7 1.5 0.2]
#  [5.  3.3 1.4 0.2]
#  [7.  3.2 4.7 1.4]
#  [6.4 3.2 4.5 1.5]
#  [6.9 3.1 4.9 1.5]
#  [5.5 2.3 4.  1.3]
#  [6.5 2.8 4.6 1.5]
#  [5.7 2.8 4.5 1.3]
#  [6.3 3.3 4.7 1.6]
#  [4.9 2.4 3.3 1. ]
#  [6.6 2.9 4.6 1.3]
#  [5.2 2.7 3.9 1.4]
#  [5.  2.  3.5 1. ]
#  [5.9 3.  4.2 1.5]
#  [6.  2.2 4.  1. ]
#  [6.1 2.9 4.7 1.4]
#  [5.6 2.9 3.6 1.3]
#  [6.7 3.1 4.4 1.4]
#  [5.6 3.  4.5 1.5]
#  [5.8 2.7 4.1 1. ]
#  [6.2 2.2 4.5 1.5]
#  [5.6 2.5 3.9 1.1]
#  [5.9 3.2 4.8 1.8]
#  [6.1 2.8 4.  1.3]
#  [6.3 2.5 4.9 1.5]
#  [6.1 2.8 4.7 1.2]
#  [6.4 2.9 4.3 1.3]
#  [6.6 3.  4.4 1.4]
#  [6.8 2.8 4.8 1.4]
#  [6.7 3.  5.  1.7]
#  [6.  2.9 4.5 1.5]
#  [5.7 2.6 3.5 1. ]
#  [5.5 2.4 3.8 1.1]
#  [5.5 2.4 3.7 1. ]
#  [5.8 2.7 3.9 1.2]
#  [6.  2.7 5.1 1.6]
#  [5.4 3.  4.5 1.5]
#  [6.  3.4 4.5 1.6]
#  [6.7 3.1 4.7 1.5]
#  [6.3 2.3 4.4 1.3]
#  [5.6 3.  4.1 1.3]
#  [5.5 2.5 4.  1.3]
#  [5.5 2.6 4.4 1.2]
#  [6.1 3.  4.6 1.4]
#  [5.8 2.6 4.  1.2]
#  [5.  2.3 3.3 1. ]
#  [5.6 2.7 4.2 1.3]
#  [5.7 3.  4.2 1.2]
#  [5.7 2.9 4.2 1.3]
#  [6.2 2.9 4.3 1.3]
#  [5.1 2.5 3.  1.1]
#  [5.7 2.8 4.1 1.3]
#  [6.3 3.3 6.  2.5]
#  [5.8 2.7 5.1 1.9]
#  [7.1 3.  5.9 2.1]
#  [6.3 2.9 5.6 1.8]
#  [6.5 3.  5.8 2.2]
#  [7.6 3.  6.6 2.1]
#  [4.9 2.5 4.5 1.7]
#  [7.3 2.9 6.3 1.8]
#  [6.7 2.5 5.8 1.8]
#  [7.2 3.6 6.1 2.5]
#  [6.5 3.2 5.1 2. ]
#  [6.4 2.7 5.3 1.9]
#  [6.8 3.  5.5 2.1]
#  [5.7 2.5 5.  2. ]
#  [5.8 2.8 5.1 2.4]
#  [6.4 3.2 5.3 2.3]
#  [6.5 3.  5.5 1.8]
#  [7.7 3.8 6.7 2.2]
#  [7.7 2.6 6.9 2.3]
#  [6.  2.2 5.  1.5]
#  [6.9 3.2 5.7 2.3]
#  [5.6 2.8 4.9 2. ]
#  [7.7 2.8 6.7 2. ]
#  [6.3 2.7 4.9 1.8]
#  [6.7 3.3 5.7 2.1]
#  [7.2 3.2 6.  1.8]
#  [6.2 2.8 4.8 1.8]
#  [6.1 3.  4.9 1.8]
#  [6.4 2.8 5.6 2.1]
#  [7.2 3.  5.8 1.6]
#  [7.4 2.8 6.1 1.9]
#  [7.9 3.8 6.4 2. ]
#  [6.4 2.8 5.6 2.2]
#  [6.3 2.8 5.1 1.5]
#  [6.1 2.6 5.6 1.4]
#  [7.7 3.  6.1 2.3]
#  [6.3 3.4 5.6 2.4]
#  [6.4 3.1 5.5 1.8]
#  [6.  3.  4.8 1.8]
#  [6.9 3.1 5.4 2.1]
#  [6.7 3.1 5.6 2.4]
#  [6.9 3.1 5.1 2.3]
#  [5.8 2.7 5.1 1.9]
#  [6.8 3.2 5.9 2.3]
#  [6.7 3.3 5.7 2.5]
#  [6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]
# ['Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa' 'Iris-setosa'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor' 'Iris-versicolor'
#  'Iris-versicolor' 'Iris-versicolor' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica'
#  'Iris-virginica' 'Iris-virginica' 'Iris-virginica' 'Iris-virginica']

# %% [markdown]
# ### A3. Indexing
# Affichez les 5 premières lignes de `features` en utilisant l’indexing.

# %%
# Votre code ici
print(features[:5])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]

# %% [markdown]
# ### A4. Extraction d’une colonne
# Créez un array `sepal_length` contenant uniquement la première colonne de `features`.
# Affichez sa `size` et son `dtype`.

# %%
# Votre code ici
sepal_length = features[:, 0]
print(sepal_length.shape)
print(sepal_length.dtype)
# Out:
# (150,)
# float64

# %% [markdown]
# ### A5. Slicing par espèce
# Utilisez le slicing pour extraire les 50 premières lignes correspondant à l’espèce *Setosa*.
# Stockez-les dans `setosa_features`.

# %%
# Votre code ici
setosa_features = features[:50]
print(setosa_features.shape)
# Out:
# (50, 4)

# %% [markdown]
# # Partie B — Statistiques Basiques et Opérations Mathématiques

# %% [markdown]
# ### B6. Moyenne par colonne
# Calculez la moyenne de chaque colonne de `features` avec `np.mean(axis=0)`.

# %%
# Votre code ici
moyenne = np.mean( features,axis=0)
print(moyenne)
# Out:
# [5.84333333 3.054      3.75866667 1.19866667]

# %% [markdown]
# ### B7. Min et Max
# Trouvez la valeur minimale et maximale de la longueur des pétales.

# %%
# Votre code ici
minimum = np.min(features[:,2], axis=0)
maximum = np.max(features[:,2], axis=0)
print(minimum, maximum)
# Out:
# 1.0 6.9

# %% [markdown]
# ### B9. Normalisation
# Normalisez les longueurs des pétales en les divisant par leur maximum.
# Stockez le résultat dans `normalized_petals`.

# %%
# Votre code ici
normalized_petals = (features[:,2])/maximum
print(normalized_petals)
# Out:
# [0.20289855 0.20289855 0.1884058  0.2173913  0.20289855 0.24637681
#  0.20289855 0.2173913  0.20289855 0.2173913  0.2173913  0.23188406
#  0.20289855 0.15942029 0.17391304 0.2173913  0.1884058  0.20289855
#  0.24637681 0.2173913  0.24637681 0.2173913  0.14492754 0.24637681
#  0.27536232 0.23188406 0.23188406 0.2173913  0.20289855 0.23188406
#  0.23188406 0.2173913  0.2173913  0.20289855 0.2173913  0.17391304
#  0.1884058  0.2173913  0.1884058  0.2173913  0.1884058  0.1884058
#  0.1884058  0.23188406 0.27536232 0.20289855 0.23188406 0.20289855
#  0.2173913  0.20289855 0.68115942 0.65217391 0.71014493 0.57971014
#  0.66666667 0.65217391 0.68115942 0.47826087 0.66666667 0.56521739
#  0.50724638 0.60869565 0.57971014 0.68115942 0.52173913 0.63768116
#  0.65217391 0.5942029  0.65217391 0.56521739 0.69565217 0.57971014
#  0.71014493 0.68115942 0.62318841 0.63768116 0.69565217 0.72463768
#  0.65217391 0.50724638 0.55072464 0.53623188 0.56521739 0.73913043
#  0.65217391 0.65217391 0.68115942 0.63768116 0.5942029  0.57971014
#  0.63768116 0.66666667 0.57971014 0.47826087 0.60869565 0.60869565
#  0.60869565 0.62318841 0.43478261 0.5942029  0.86956522 0.73913043
#  0.85507246 0.8115942  0.84057971 0.95652174 0.65217391 0.91304348
#  0.84057971 0.88405797 0.73913043 0.76811594 0.79710145 0.72463768
#  0.73913043 0.76811594 0.79710145 0.97101449 1.         0.72463768
#  0.82608696 0.71014493 0.97101449 0.71014493 0.82608696 0.86956522
#  0.69565217 0.71014493 0.8115942  0.84057971 0.88405797 0.92753623
#  0.8115942  0.73913043 0.8115942  0.88405797 0.8115942  0.79710145
#  0.69565217 0.7826087  0.8115942  0.73913043 0.73913043 0.85507246
#  0.82608696 0.75362319 0.72463768 0.75362319 0.7826087  0.73913043]

# %% [markdown]
# ### B10. Somme cumulée
# Calculez la somme cumulée des largeurs des pétales pour Versicolor.
# Affichez les 10 premières valeurs.

# %%
# Votre code ici
somme_cumulee = np.cumsum(features[51:101 ,3])
print(somme_cumulee[:10])
# Out:
# [ 1.5  3.   4.3  5.8  7.1  8.7  9.7 11.  12.4 13.4]

# %% [markdown]
# ### B10. Somme cumulée
# Calculez la somme cumulée des largeurs des pétales pour Versicolor.
# Affichez les 10 premières valeurs.

# %%
# Votre code ici
somme_cumulee = np.cumsum(features[51:101 ,3])
print(somme_cumulee[:10])
# Out:
# [ 1.5  3.   4.3  5.8  7.1  8.7  9.7 11.  12.4 13.4]

# %% [markdown]
# # Partie C — Transformations Avancées avec NumPy

# %% [markdown]
# ### C11. Espèces uniques
# Listez les espèces uniques avec `np.unique` et comptez leurs occurrences.

# %%
# Votre code ici
import numpy as np
especes_uniques, counts = np.unique(species, return_counts=True)
print(especes_uniques)
print(counts)
# Out:
# ['Iris-setosa' 'Iris-versicolor' 'Iris-virginica']
# [50 50 50]

# %% [markdown]
# ### C12. Reshape par espèce
# Transformez `features` en un array de forme `(3, 50, 4)` nommé `features_by_species`.

# %%
# Votre code ici
features_by_species = features.reshape(3, 50, 4)
print(features.shape)
print(features_by_species.shape)
# Out:
# (150, 4)
# (3, 50, 4)

# %% [markdown]
# ### C13. Concaténation
# Concaténez horizontalement les moyennes par colonne avec un array de zéros.

# %%
# Votre code ici
concat = np.concatenate((moyenne.reshape(4, 1), np.zeros((4, 1))), axis=1)
print(concat)
# Out:
# [[5.84333333 0.        ]
#  [3.054      0.        ]
#  [3.75866667 0.        ]
#  [1.19866667 0.        ]]

# %% [markdown]
# ### C14. Data cleaning (simulation)
# Simulez des valeurs NaN et remplacez-les avec `np.nan_to_num`.

# %%
# Votre code ici
data_cleaned = np.nan_to_num(data)
print(data_cleaned)
# Out:
# [['1' '5.1' '3.5' '1.4' '0.2' 'Iris-setosa']
#  ['2' '4.9' '3.0' '1.4' '0.2' 'Iris-setosa']
#  ['3' '4.7' '3.2' '1.3' '0.2' 'Iris-setosa']
#  ['4' '4.6' '3.1' '1.5' '0.2' 'Iris-setosa']
#  ['5' '5.0' '3.6' '1.4' '0.2' 'Iris-setosa']
#  ['6' '5.4' '3.9' '1.7' '0.4' 'Iris-setosa']
#  ['7' '4.6' '3.4' '1.4' '0.3' 'Iris-setosa']
#  ['8' '5.0' '3.4' '1.5' '0.2' 'Iris-setosa']
#  ['9' '4.4' '2.9' '1.4' '0.2' 'Iris-setosa']
#  ['10' '4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['11' '5.4' '3.7' '1.5' '0.2' 'Iris-setosa']
#  ['12' '4.8' '3.4' '1.6' '0.2' 'Iris-setosa']
#  ['13' '4.8' '3.0' '1.4' '0.1' 'Iris-setosa']
#  ['14' '4.3' '3.0' '1.1' '0.1' 'Iris-setosa']
#  ['15' '5.8' '4.0' '1.2' '0.2' 'Iris-setosa']
#  ['16' '5.7' '4.4' '1.5' '0.4' 'Iris-setosa']
#  ['17' '5.4' '3.9' '1.3' '0.4' 'Iris-setosa']
#  ['18' '5.1' '3.5' '1.4' '0.3' 'Iris-setosa']
#  ['19' '5.7' '3.8' '1.7' '0.3' 'Iris-setosa']
#  ['20' '5.1' '3.8' '1.5' '0.3' 'Iris-setosa']
#  ['21' '5.4' '3.4' '1.7' '0.2' 'Iris-setosa']
#  ['22' '5.1' '3.7' '1.5' '0.4' 'Iris-setosa']
#  ['23' '4.6' '3.6' '1.0' '0.2' 'Iris-setosa']
#  ['24' '5.1' '3.3' '1.7' '0.5' 'Iris-setosa']
#  ['25' '4.8' '3.4' '1.9' '0.2' 'Iris-setosa']
#  ['26' '5.0' '3.0' '1.6' '0.2' 'Iris-setosa']
#  ['27' '5.0' '3.4' '1.6' '0.4' 'Iris-setosa']
#  ['28' '5.2' '3.5' '1.5' '0.2' 'Iris-setosa']
#  ['29' '5.2' '3.4' '1.4' '0.2' 'Iris-setosa']
#  ['30' '4.7' '3.2' '1.6' '0.2' 'Iris-setosa']
#  ['31' '4.8' '3.1' '1.6' '0.2' 'Iris-setosa']
#  ['32' '5.4' '3.4' '1.5' '0.4' 'Iris-setosa']
#  ['33' '5.2' '4.1' '1.5' '0.1' 'Iris-setosa']
#  ['34' '5.5' '4.2' '1.4' '0.2' 'Iris-setosa']
#  ['35' '4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['36' '5.0' '3.2' '1.2' '0.2' 'Iris-setosa']
#  ['37' '5.5' '3.5' '1.3' '0.2' 'Iris-setosa']
#  ['38' '4.9' '3.1' '1.5' '0.1' 'Iris-setosa']
#  ['39' '4.4' '3.0' '1.3' '0.2' 'Iris-setosa']
#  ['40' '5.1' '3.4' '1.5' '0.2' 'Iris-setosa']
#  ['41' '5.0' '3.5' '1.3' '0.3' 'Iris-setosa']
#  ['42' '4.5' '2.3' '1.3' '0.3' 'Iris-setosa']
#  ['43' '4.4' '3.2' '1.3' '0.2' 'Iris-setosa']
#  ['44' '5.0' '3.5' '1.6' '0.6' 'Iris-setosa']
#  ['45' '5.1' '3.8' '1.9' '0.4' 'Iris-setosa']
#  ['46' '4.8' '3.0' '1.4' '0.3' 'Iris-setosa']
#  ['47' '5.1' '3.8' '1.6' '0.2' 'Iris-setosa']
#  ['48' '4.6' '3.2' '1.4' '0.2' 'Iris-setosa']
#  ['49' '5.3' '3.7' '1.5' '0.2' 'Iris-setosa']
#  ['50' '5.0' '3.3' '1.4' '0.2' 'Iris-setosa']
#  ['51' '7.0' '3.2' '4.7' '1.4' 'Iris-versicolor']
#  ['52' '6.4' '3.2' '4.5' '1.5' 'Iris-versicolor']
#  ['53' '6.9' '3.1' '4.9' '1.5' 'Iris-versicolor']
#  ['54' '5.5' '2.3' '4.0' '1.3' 'Iris-versicolor']
#  ['55' '6.5' '2.8' '4.6' '1.5' 'Iris-versicolor']
#  ['56' '5.7' '2.8' '4.5' '1.3' 'Iris-versicolor']
#  ['57' '6.3' '3.3' '4.7' '1.6' 'Iris-versicolor']
#  ['58' '4.9' '2.4' '3.3' '1.0' 'Iris-versicolor']
#  ['59' '6.6' '2.9' '4.6' '1.3' 'Iris-versicolor']
#  ['60' '5.2' '2.7' '3.9' '1.4' 'Iris-versicolor']
#  ['61' '5.0' '2.0' '3.5' '1.0' 'Iris-versicolor']
#  ['62' '5.9' '3.0' '4.2' '1.5' 'Iris-versicolor']
#  ['63' '6.0' '2.2' '4.0' '1.0' 'Iris-versicolor']
#  ['64' '6.1' '2.9' '4.7' '1.4' 'Iris-versicolor']
#  ['65' '5.6' '2.9' '3.6' '1.3' 'Iris-versicolor']
#  ['66' '6.7' '3.1' '4.4' '1.4' 'Iris-versicolor']
#  ['67' '5.6' '3.0' '4.5' '1.5' 'Iris-versicolor']
#  ['68' '5.8' '2.7' '4.1' '1.0' 'Iris-versicolor']
#  ['69' '6.2' '2.2' '4.5' '1.5' 'Iris-versicolor']
#  ['70' '5.6' '2.5' '3.9' '1.1' 'Iris-versicolor']
#  ['71' '5.9' '3.2' '4.8' '1.8' 'Iris-versicolor']
#  ['72' '6.1' '2.8' '4.0' '1.3' 'Iris-versicolor']
#  ['73' '6.3' '2.5' '4.9' '1.5' 'Iris-versicolor']
#  ['74' '6.1' '2.8' '4.7' '1.2' 'Iris-versicolor']
#  ['75' '6.4' '2.9' '4.3' '1.3' 'Iris-versicolor']
#  ['76' '6.6' '3.0' '4.4' '1.4' 'Iris-versicolor']
#  ['77' '6.8' '2.8' '4.8' '1.4' 'Iris-versicolor']
#  ['78' '6.7' '3.0' '5.0' '1.7' 'Iris-versicolor']
#  ['79' '6.0' '2.9' '4.5' '1.5' 'Iris-versicolor']
#  ['80' '5.7' '2.6' '3.5' '1.0' 'Iris-versicolor']
#  ['81' '5.5' '2.4' '3.8' '1.1' 'Iris-versicolor']
#  ['82' '5.5' '2.4' '3.7' '1.0' 'Iris-versicolor']
#  ['83' '5.8' '2.7' '3.9' '1.2' 'Iris-versicolor']
#  ['84' '6.0' '2.7' '5.1' '1.6' 'Iris-versicolor']
#  ['85' '5.4' '3.0' '4.5' '1.5' 'Iris-versicolor']
#  ['86' '6.0' '3.4' '4.5' '1.6' 'Iris-versicolor']
#  ['87' '6.7' '3.1' '4.7' '1.5' 'Iris-versicolor']
#  ['88' '6.3' '2.3' '4.4' '1.3' 'Iris-versicolor']
#  ['89' '5.6' '3.0' '4.1' '1.3' 'Iris-versicolor']
#  ['90' '5.5' '2.5' '4.0' '1.3' 'Iris-versicolor']
#  ['91' '5.5' '2.6' '4.4' '1.2' 'Iris-versicolor']
#  ['92' '6.1' '3.0' '4.6' '1.4' 'Iris-versicolor']
#  ['93' '5.8' '2.6' '4.0' '1.2' 'Iris-versicolor']
#  ['94' '5.0' '2.3' '3.3' '1.0' 'Iris-versicolor']
#  ['95' '5.6' '2.7' '4.2' '1.3' 'Iris-versicolor']
#  ['96' '5.7' '3.0' '4.2' '1.2' 'Iris-versicolor']
#  ['97' '5.7' '2.9' '4.2' '1.3' 'Iris-versicolor']
#  ['98' '6.2' '2.9' '4.3' '1.3' 'Iris-versicolor']
#  ['99' '5.1' '2.5' '3.0' '1.1' 'Iris-versicolor']
#  ['100' '5.7' '2.8' '4.1' '1.3' 'Iris-versicolor']
#  ['101' '6.3' '3.3' '6.0' '2.5' 'Iris-virginica']
#  ['102' '5.8' '2.7' '5.1' '1.9' 'Iris-virginica']
#  ['103' '7.1' '3.0' '5.9' '2.1' 'Iris-virginica']
#  ['104' '6.3' '2.9' '5.6' '1.8' 'Iris-virginica']
#  ['105' '6.5' '3.0' '5.8' '2.2' 'Iris-virginica']
#  ['106' '7.6' '3.0' '6.6' '2.1' 'Iris-virginica']
#  ['107' '4.9' '2.5' '4.5' '1.7' 'Iris-virginica']
#  ['108' '7.3' '2.9' '6.3' '1.8' 'Iris-virginica']
#  ['109' '6.7' '2.5' '5.8' '1.8' 'Iris-virginica']
#  ['110' '7.2' '3.6' '6.1' '2.5' 'Iris-virginica']
#  ['111' '6.5' '3.2' '5.1' '2.0' 'Iris-virginica']
#  ['112' '6.4' '2.7' '5.3' '1.9' 'Iris-virginica']
#  ['113' '6.8' '3.0' '5.5' '2.1' 'Iris-virginica']
#  ['114' '5.7' '2.5' '5.0' '2.0' 'Iris-virginica']
#  ['115' '5.8' '2.8' '5.1' '2.4' 'Iris-virginica']
#  ['116' '6.4' '3.2' '5.3' '2.3' 'Iris-virginica']
#  ['117' '6.5' '3.0' '5.5' '1.8' 'Iris-virginica']
#  ['118' '7.7' '3.8' '6.7' '2.2' 'Iris-virginica']
#  ['119' '7.7' '2.6' '6.9' '2.3' 'Iris-virginica']
#  ['120' '6.0' '2.2' '5.0' '1.5' 'Iris-virginica']
#  ['121' '6.9' '3.2' '5.7' '2.3' 'Iris-virginica']
#  ['122' '5.6' '2.8' '4.9' '2.0' 'Iris-virginica']
#  ['123' '7.7' '2.8' '6.7' '2.0' 'Iris-virginica']
#  ['124' '6.3' '2.7' '4.9' '1.8' 'Iris-virginica']
#  ['125' '6.7' '3.3' '5.7' '2.1' 'Iris-virginica']
#  ['126' '7.2' '3.2' '6.0' '1.8' 'Iris-virginica']
#  ['127' '6.2' '2.8' '4.8' '1.8' 'Iris-virginica']
#  ['128' '6.1' '3.0' '4.9' '1.8' 'Iris-virginica']
#  ['129' '6.4' '2.8' '5.6' '2.1' 'Iris-virginica']
#  ['130' '7.2' '3.0' '5.8' '1.6' 'Iris-virginica']
#  ['131' '7.4' '2.8' '6.1' '1.9' 'Iris-virginica']
#  ['132' '7.9' '3.8' '6.4' '2.0' 'Iris-virginica']
#  ['133' '6.4' '2.8' '5.6' '2.2' 'Iris-virginica']
#  ['134' '6.3' '2.8' '5.1' '1.5' 'Iris-virginica']
#  ['135' '6.1' '2.6' '5.6' '1.4' 'Iris-virginica']
#  ['136' '7.7' '3.0' '6.1' '2.3' 'Iris-virginica']
#  ['137' '6.3' '3.4' '5.6' '2.4' 'Iris-virginica']
#  ['138' '6.4' '3.1' '5.5' '1.8' 'Iris-virginica']
#  ['139' '6.0' '3.0' '4.8' '1.8' 'Iris-virginica']
#  ['140' '6.9' '3.1' '5.4' '2.1' 'Iris-virginica']
#  ['141' '6.7' '3.1' '5.6' '2.4' 'Iris-virginica']
#  ['142' '6.9' '3.1' '5.1' '2.3' 'Iris-virginica']
#  ['143' '5.8' '2.7' '5.1' '1.9' 'Iris-virginica']
#  ['144' '6.8' '3.2' '5.9' '2.3' 'Iris-virginica']
#  ['145' '6.7' '3.3' '5.7' '2.5' 'Iris-virginica']
#  ['146' '6.7' '3.0' '5.2' '2.3' 'Iris-virginica']
#  ['147' '6.3' '2.5' '5.0' '1.9' 'Iris-virginica']
#  ['148' '6.5' '3.0' '5.2' '2.0' 'Iris-virginica']
#  ['149' '6.2' '3.4' '5.4' '2.3' 'Iris-virginica']
#  ['150' '5.9' '3.0' '5.1' '1.8' 'Iris-virginica']]

# %% [markdown]
# ### C15. Broadcasting
# Ajoutez 1 à toutes les valeurs de la première colonne de `features`.

# %%
print(features[:5, 0])
# Out:
# [5.1 4.9 4.7 4.6 5. ]

# %%
# Votre code ici
features[:, 0] = features[:, 0] + 1
print(features[:5, 0])
# Out:
# [6.1 5.9 5.7 5.6 6. ]

# %% [markdown]
# ### C16. np.where
# Créez un array binaire indiquant si la longueur des pétales est supérieure à 4.0.

# %%
# Votre code ici
binaire_array = (features[:, 2] > 4.0)
print(binaire_array)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True  True  True False  True  True  True False  True False
#  False  True False  True False  True  True  True  True False  True False
#   True  True  True  True  True  True  True False False False False  True
#   True  True  True  True  True False  True  True False False  True  True
#   True  True False  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True  True  True  True  True  True  True
#   True  True  True  True  True  True]

# %% [markdown]
# # Partie D — Visualisation avec Matplotlib (Plots Simples)

# %% [markdown]
# ### D17. Line plot
# Line plot des longueurs des sépales pour les 50 premières fleurs.

# %%
# Votre code ici
#premierement on selection les donnees a tracer (les 50 premiers fleurs)
sepal_length = features[:, 0]
sepal_length_50 = sepal_length[:50]
indices = np.arange(1, 51)

plt.figure(figsize=(10, 6))
plt.plot(indices, sepal_length_50)
plt.title('Longueur des sepales des premiers 50 fleurs')
plt.xlabel('numero de fleurs')
plt.ylabel('longueur sepales')
plt.legend()
plt.show()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_33048\1607746226.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %% [markdown]
# ### D18. Scatter plot
# Scatter plot : longueur vs largeur des pétales.

# %%
# Votre code ici
longueur_petales = features[:, 2]
largeur_petales = features[:, 3]

plt.figure(figsize=(10, 6))
plt.scatter(longueur_petales, largeur_petales)
plt.title('Longueur et largeur des petales')
plt.xlabel('longueur petales')
plt.ylabel('largeur petales')
plt.show()

# %% [markdown]
# ### D19. Bar chart
# Bar chart des moyennes des quatre caractéristiques.

# %%
# Votre code ici
nom_carast = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
plt.bar(nom_carast, moyenne, color =['red','purple','yellow','green'])
# Out:
# <BarContainer object of 4 artists>

# %% [markdown]
# ### D20. Histogram
# Histogramme de la largeur des sépales (10 bins).

# %%
# Votre code ici
plt.hist(features[:, 1], bins=10)
# Out:
# (array([ 4.,  7., 22., 24., 38., 31.,  9., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### D21. Boxplot par espèce
# Boxplot des longueurs des pétales par espèce.

# %%
# Votre code ici
plt.figsize=(10, 6)
data_box = [
    features[:50, 2],
    features[50:100, 2],
    features[100:, 2]
]

plt.boxplot(data_box, labels = ['versicolor','setosa','virginica'])
plt.show()
# Out:
# C:\Users\RPC\AppData\Local\Temp\ipykernel_33048\2659634151.py:9: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data_box, labels = ['versicolor','setosa','virginica'])

# %% [markdown]
# # Partie E — Visualisations Avancées

# %% [markdown]
# ### E22. Subplots comparatifs
# Deux scatter plots côte à côte : Setosa vs Versicolor.

# %%
# Votre code ici

# %% [markdown]
# ### E23. Grille 2x2
# Histogrammes des 4 caractéristiques avec `plt.subplots(2,2)`.

# %%
# Votre code ici

# %% [markdown]
# ### E24. Bar chart avec error bars
# Moyennes par espèce avec écart-type.

# %%
# Votre code ici

# %% [markdown]
# ### E25. Scatter coloré par espèce
# Scatter plot avec couleurs par espèce.

# %%
# Votre code ici

# %% [markdown]
# ### E26. Line plot superposé
# Cumsum des largeurs des pétales par espèce.

# %%
# Votre code ici

# %% [markdown]
# # Partie F — Mini-Analyse Finale

# %% [markdown]
# ### F27. Corrélations
# Calculez la matrice de corrélation avec `np.corrcoef`.

# %%
# Votre code ici

# %% [markdown]
# ### F28. Visualisation des corrélations
# Visualisez les corrélations sous forme de bar chart ou scatter.

# %%
# Votre code ici

# %% [markdown]
# ### F29. Variance par espèce
# Identifiez l’espèce avec la plus grande variance globale et visualisez ses distributions.

# %%
# Votre code ici

# %% [markdown]
# ### F30. Conclusion
# Rédigez une conclusion contenant **3 insights** issus de votre analyse.

# %% [markdown]
# 1) ...
# 2) ...
# 3) ...
